# %% [markdown]
# # pendenza di una retta

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
def f(x):
    return(x**2-2*x-3)

# %%
y=f(x)

# %%
print(f(0.5))
# Out:
# -3.75

# %% [markdown]
# creazione di un vettore che abbia valori di *x* da -10 a 10 con incremernto di 0.1

# %%
x=np.linspace(-10,10,201)

# %% [markdown]
# scewgliam un valore di dx, che in questo caso sarà 0.01

# %%
dx=0.1

# %%
m=(f(dx-x)-f(x))/dx

# %%
plt.figure(figsize=[5,5])
plt.plot(x,y)
plt.plot(x,m)
plt.axis([-10,10,-10,10])
plt.gca().set_aspect("equal")
plt.grid()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# regressione polinomiale su m(x)

# %%
np.polyfit(x,m,1)
# Out:
# array([38. , -1.9])
