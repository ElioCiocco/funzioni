# %% [markdown]
# # pendenza di una retta

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
def f(x):
    return(x**2-2*x-3)

# %%
y=f(x)

# %%
print(f(0.5))
# Out:
# -3.75

# %% [markdown]
# creazione di un vettore che abbia valori di *x* da -10 a 10 con incremernto di 0.1

# %%
x=np.linspace(-10,10,2001)
print(x)
# Out:
# [-10.    -9.99  -9.98 ...   9.98   9.99  10.  ]

# %% [markdown]
# scewgliam un valore di dx, che in questo caso sarà 0.01

# %%
dx=0.01

# %%
m=(f(dx-x)-f(x))/dx
print(m)
# Out:
# [-3981.99 -3978.01 -3974.03 ...  3970.05  3974.03  3978.01]

# %%
plt.plot(x,y)
plt.plot(x,m)
plt.axis([-10,10,-10,10])
plt.gca().set_aspect("equal")
plt.grid()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
